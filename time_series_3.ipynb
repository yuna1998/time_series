# %% [markdown]
# <a href="https://colab.research.google.com/github/yuna1998/time_series/blob/main/time_series_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Gernerate the AR(1) model
# a)

# %%
error <- rnorm(200,0,1)

# %% [markdown]
# b)

# %%
error_0 <- 0
y_0 <- 0

# %% [markdown]
# c) phi = -0.7

# %%
phi <- -0.7
y_ar <- numeric(200)

# %%
for (i in 1:200){
    if(i != 1){y_0 <- y_ar[i-1]}
    y_ar[i] <- y_0*phi + error[i]
}
plot(y_ar, type = "b", pch = 19)
# Out:
# plot without title

# %% [markdown]
# phi  : -0.5

# %%
phi <- -0.5
y_ar <- numeric(200)
for (i in 1:200){
    if(i != 1){y_0 <- y_ar[i-1]}
    y_ar[i] <- y_0*phi + error[i]
}
plot(y_ar, type = "b", pch = 19)
# Out:
# plot without title

# %% [markdown]
# phi : -0.2

# %%
phi <- -0.2
y_ar <- numeric(200)
for (i in 1:200){
    if(i != 1){y_0 <- y_ar[i-1]}
    y_ar[i] <- y_0*phi + error[i]
}
plot(y_ar, type = "b", pch = 19)
# Out:
# plot without title

# %% [markdown]
# phi : 0.2

# %%
phi <- 0.2
y_ar <- numeric(200)
for (i in 1:200){
    if(i != 1){y_0 <- y_ar[i-1]}
    y_ar[i] <- y_0*phi + error[i]
}
plot(y_ar, type = "b", pch = 19)
# Out:
# plot without title

# %% [markdown]
# phi : 0.5

# %%
phi <- 0.5
y_ar <- numeric(200)
for (i in 1:200){
    if(i != 1){y_0 <- y_ar[i-1]}
    y_ar[i] <- y_0*phi + error[i]
}
plot(y_ar, type = "b", pch = 19)
# Out:
# plot without title

# %% [markdown]
# phi : 0.7

# %%
phi <- 0.7
y_ar <- numeric(200)
for (i in 1:200){
    if(i != 1){y_0 <- y_ar[i-1]}
    y_ar[i] <- y_0*phi + error[i]
}
plot(y_ar, type = "b", pch = 19)
# Out:
# plot without title

# %% [markdown]
# #2. Generate the MA(1) model
# a)

# %%
error <- rnorm(200,0,1)
error_0 <- 0

# %% [markdown]
# b)

# %%
theta <- -0.9
y_ma <- numeric(200)
for (i in 1 : 200){
    if( i != 1){error_0 <- error[i-1]}
    y_ma[i] <- error[i] + error_0  * theta
}
plot(y_ma, type = "b", pch = 19)
# Out:
# plot without title

# %%
theta <- -0.7
y_ma <- numeric(200)
for (i in 1 : 200){
    if( i != 1){error_0 <- error[i-1]}
    y_ma[i] <- error[i] + error_0  * theta
}
plot(y_ma, type = "b", pch = 19)
# Out:
# plot without title

# %%
theta <- -0.3
y_ma <- numeric(200)
for (i in 1 : 200){
    if( i != 1){error_0 <- error[i-1]}
    y_ma[i] <- error[i] + error_0  * theta
}
plot(y_ma, type = "b", pch = 19)
# Out:
# plot without title

# %%
theta <- 0.3
y_ma <- numeric(200)
for (i in 1 : 200){
    if( i != 1){error_0 <- error[i-1]}
    y_ma[i] <- error[i] + error_0  * theta
}
plot(y_ma, type = "b", pch = 19)
# Out:
# plot without title

# %%
theta <- 0.7
y_ma <- numeric(200)
for (i in 1 : 200){
    if( i != 1){error_0 <- error[i-1]}
    y_ma[i] <- error[i] + error_0  * theta
}
plot(y_ma, type = "b", pch = 19)
# Out:
# plot without title

# %%
theta <- 0.9
y_ma <- numeric(200)
for (i in 1 : 200){
    if( i != 1){error_0 <- error[i-1]}
    y_ma[i] <- error[i] + error_0  * theta
}
plot(y_ma, type = "b", pch = 19)
# Out:
# plot without title

# %% [markdown]
# #3. Consider the time series model
# a) Is tis a stationary time series process?
